# %%
numbers = [10,20,30,40,50]
print(numbers)
numbers.append(60)
print(numbers)
# Out:
# [10, 20, 30, 40, 50]
# [10, 20, 30, 40, 50, 60]

# %%
print(len(numbers))
# Out:
# 6

# %%
numbers[2] = 40
numbers
# Out:
# [10, 20, 40, 40, 50, 60]

# %%
numbers.index(50)
# Out:
# 4

# %%
numbers = [10,20,30,40,50,60]
numbers.remove(60)
numbers

# %%
print(numbers)
# Out:
# [10, 20, 30, 40, 35, 50, 100]

# %%
numbers.insert(2,44)

# %%
print(numbers)
# Out:
# [10, 20, 44, 30, 40, 35, 50, 100]

# %%
numbers.append([15,20,25,30])
print(numbers)
# Out:
# [10, 20, 44, 30, 40, 35, 50, 100, [15, 20, 25, 30], [15, 20, 25, 30]]

# %%
numbers[7]
# Out:
# 100

# %%
print(numbers)
# Out:
# [10, 20, 44, 30, 40, 35, 50, 100, [15, 20, 25, 30], [15, 20, 25, 30]]

# %%
example = [2,1,5,90,30]
example.sort()
example
# Out:
# [1, 2, 5, 30, 90]

# %%
example.reverse()
example
# Out:
# [90, 30, 5, 2, 1]

# %%
new = example.copy()
new
# Out:
# [90, 30, 5, 2, 1]

# %%
new = (10,20,30)
print(new)
# Out:
# (10, 20, 30)

# %%
print(type(new))
# Out:
# <class 'tuple'>

# %%
print(len(new))
# Out:
# 3

# %%
new = (1,23,10,34,56,688,67)
print(new)
# Out:
# (1, 23, 10, 34, 56, 688, 67)

# %%
new = (1, 23, 10, 34, 56, 688, 67)
new.index(10)

print(sorted(new))
new.count(34)
# Out:
# [1, 10, 23, 34, 56, 67, 688]
# 1

# %% [markdown]
# SETS

# %%
num = {10,20,30,20,10}
print(num)
num.add(40)
num
num.update([30,40,50])
# Out:
# {10, 20, 30}
# {10, 20, 30, 40, 50}

# %%
num.remove(10)
num
# Out:
# {20, 30, 40, 50}

# %%
num.add(60)
num
# Out:
# {20, 30, 40, 50, 60}

# %%
(len(num))
# Out:
# 5

# %%
print(type(num))
# Out:
# <class 'set'>

# %%
num.pop()
num
# Out:
# {20, 30, 50, 60}

# %%
num.discard(30)
num
# Out:
# {20, 50, 60}

# %%
num.clear
num
# Out:
# {20, 50, 60}

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}
print(A | B)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
print(A & B)
# Out:
# {3, 4}

# %%
print(A - B)
# Out:
# {1, 2}

# %%
print(A ^ B)
# Out:
# {1, 2, 5, 6}

# %% [markdown]
# Dictonanry

# %%
student = {
    "name":"Rahul",
    "age":22,
    "course" :"python"
}
print(student["name"])
student["city"] = "Banglore"
student.update({"age":24,"city":"mysore"})
# Out:
# Rahul

# %%
type(student)
# Out:
# dict

# %%
print(len(student))
# Out:
# 4

# %%
a = 150
b = -212
c = 0

if a > b and a > c:
    print("Largest number is", a)
elif b > a and b > c:
    print("Largest number is", b)
else:
    print("Largest number is", c)
# Out:
# Largest number is 150

# %%
day = int(input("Enter the day number :"))
match day:
  case 1: print("monday")
  case 2: print("Tuesday")
  case 3: print("wednesday")
  case 4: print("Thursday")
  case 5: print("Friday")
  case 6: print("Saturday")
  case 7: print("Sunday")
  case _: print("Invalid day")
# Out:
# Enter the day number :5
# Friday

# %%
dividend = 153
divisor = 10

quotient = dividend // divisor
remainder = dividend % divisor

print("Dividend =", dividend)
print("Divisor =", divisor)
print("Quotient =", quotient)
print("Remainder =", remainder)
# Out:
# Dividend = 153
# Divisor = 10
# Quotient = 15
# Remainder = 3
