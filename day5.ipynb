# %%
#data cleaning

# %%
import pandas as pd
data = pd.read_excel("/content/employee_data_10x9.xlsx")
data
# Out:
#   Employee_ID    Name   Age Department   Salary  Experience       City  \
# 0        E001   Rahul  24.0         IT  35000.0         1.0  Bangalore
# 1        E002   Priya  27.0         HR  42000.0         3.0     Mysore
# 2        E003    Arun   NaN    Finance  50000.0         5.0  Bangalore
# 3        E004   Sneha  25.0         IT      NaN         2.0      Hubli
# 4        E005   Kiran  31.0  Marketing  55000.0         NaN    Dharwad
# 5        E006  Anjali  26.0         IT  41000.0         3.0        NaN
# 6        E007   Rohit  28.0    Finance  48000.0         4.0  Bangalore
# 7        E008   Meena  30.0         HR      NaN         6.0     Mysore
# 8        E009   Vijay   NaN         IT  32000.0         1.0      Hubli
# 9        E010    Neha  27.0  Marketing  46000.0         4.0        NaN
#
#    Gender  Performance
# 0    Male         85.0
# 1  Female         90.0
# 2    Male         78.0
# 3  Female         88.0
# 4    Male         92.0
# 5  Female         81.0
# ...

# %%
data.isnull()
# Out:
#    Employee_ID   Name    Age  Department  Salary  Experience   City  Gender  \
# 0        False  False  False       False   False       False  False   False
# 1        False  False  False       False   False       False  False   False
# 2        False  False   True       False   False       False  False   False
# 3        False  False  False       False    True       False  False   False
# 4        False  False  False       False   False        True  False   False
# 5        False  False  False       False   False       False   True   False
# 6        False  False  False       False   False       False  False   False
# 7        False  False  False       False    True       False  False   False
# 8        False  False   True       False   False       False  False   False
# 9        False  False  False       False   False       False   True   False
#
#    Performance
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6         True
# ...

# %%
data.isnull().sum()
# Out:
# Employee_ID    0
# Name           0
# Age            2
# Department     0
# Salary         2
# Experience     1
# City           2
# Gender         0
# Performance    1
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# np.int64(8)

# %%
data['City']=data['City'].fillna('Mangalure')
data
# Out:
#   Employee_ID    Name   Age Department   Salary  Experience       City  \
# 0        E001   Rahul  24.0         IT  35000.0         1.0  Bangalore
# 1        E002   Priya  27.0         HR  42000.0         3.0     Mysore
# 2        E003    Arun   NaN    Finance  50000.0         5.0  Bangalore
# 3        E004   Sneha  25.0         IT      NaN         2.0      Hubli
# 4        E005   Kiran  31.0  Marketing  55000.0         NaN    Dharwad
# 5        E006  Anjali  26.0         IT  41000.0         3.0  Mangalure
# 6        E007   Rohit  28.0    Finance  48000.0         4.0  Bangalore
# 7        E008   Meena  30.0         HR      NaN         6.0     Mysore
# 8        E009   Vijay   NaN         IT  32000.0         1.0      Hubli
# 9        E010    Neha  27.0  Marketing  46000.0         4.0  Mangalure
#
#    Gender  Performance
# 0    Male         85.0
# 1  Female         90.0
# 2    Male         78.0
# 3  Female         88.0
# 4    Male         92.0
# 5  Female         81.0
# ...

# %%
data['Age']=data['Age'].fillna(24)
data
# Out:
#   Employee_ID    Name   Age Department   Salary  Experience       City  \
# 0        E001   Rahul  24.0         IT  35000.0         1.0  Bangalore
# 1        E002   Priya  27.0         HR  42000.0         3.0     Mysore
# 2        E003    Arun  24.0    Finance  50000.0         5.0  Bangalore
# 3        E004   Sneha  25.0         IT      NaN         2.0      Hubli
# 4        E005   Kiran  31.0  Marketing  55000.0         NaN    Dharwad
# 5        E006  Anjali  26.0         IT  41000.0         3.0  Mangalure
# 6        E007   Rohit  28.0    Finance  48000.0         4.0  Bangalore
# 7        E008   Meena  30.0         HR      NaN         6.0     Mysore
# 8        E009   Vijay  24.0         IT  32000.0         1.0      Hubli
# 9        E010    Neha  27.0  Marketing  46000.0         4.0  Mangalure
#
#    Gender  Performance
# 0    Male         85.0
# 1  Female         90.0
# 2    Male         78.0
# 3  Female         88.0
# 4    Male         92.0
# 5  Female         81.0
# ...

# %%
data['Salary']=data['Salary'].fillna(50000)
data
# Out:
#   Employee_ID    Name   Age Department   Salary  Experience       City  \
# 0        E001   Rahul  24.0         IT  35000.0         1.0  Bangalore
# 1        E002   Priya  27.0         HR  42000.0         3.0     Mysore
# 2        E003    Arun  24.0    Finance  50000.0         5.0  Bangalore
# 3        E004   Sneha  25.0         IT  50000.0         2.0      Hubli
# 4        E005   Kiran  31.0  Marketing  55000.0         NaN    Dharwad
# 5        E006  Anjali  26.0         IT  41000.0         3.0  Mangalure
# 6        E007   Rohit  28.0    Finance  48000.0         4.0  Bangalore
# 7        E008   Meena  30.0         HR  50000.0         6.0     Mysore
# 8        E009   Vijay  24.0         IT  32000.0         1.0      Hubli
# 9        E010    Neha  27.0  Marketing  46000.0         4.0  Mangalure
#
#    Gender  Performance
# 0    Male         85.0
# 1  Female         90.0
# 2    Male         78.0
# 3  Female         88.0
# 4    Male         92.0
# 5  Female         81.0
# ...

# %%
data['Experience']=data['Experience'].fillna(8)
data
# Out:
#   Employee_ID    Name   Age Department   Salary  Experience       City  \
# 0        E001   Rahul  24.0         IT  35000.0         1.0  Bangalore
# 1        E002   Priya  27.0         HR  42000.0         3.0     Mysore
# 2        E003    Arun  24.0    Finance  50000.0         5.0  Bangalore
# 3        E004   Sneha  25.0         IT  50000.0         2.0      Hubli
# 4        E005   Kiran  31.0  Marketing  55000.0         8.0    Dharwad
# 5        E006  Anjali  26.0         IT  41000.0         3.0  Mangalure
# 6        E007   Rohit  28.0    Finance  48000.0         4.0  Bangalore
# 7        E008   Meena  30.0         HR  50000.0         6.0     Mysore
# 8        E009   Vijay  24.0         IT  32000.0         1.0      Hubli
# 9        E010    Neha  27.0  Marketing  46000.0         4.0  Mangalure
#
#    Gender  Performance
# 0    Male         85.0
# 1  Female         90.0
# 2    Male         78.0
# 3  Female         88.0
# 4    Male         92.0
# 5  Female         81.0
# ...

# %%
data['Performance']=data['Performance'].fillna(90)
data
# Out:
#   Employee_ID    Name   Age Department   Salary  Experience       City  \
# 0        E001   Rahul  24.0         IT  35000.0         1.0  Bangalore
# 1        E002   Priya  27.0         HR  42000.0         3.0     Mysore
# 2        E003    Arun  24.0    Finance  50000.0         5.0  Bangalore
# 3        E004   Sneha  25.0         IT  50000.0         2.0      Hubli
# 4        E005   Kiran  31.0  Marketing  55000.0         8.0    Dharwad
# 5        E006  Anjali  26.0         IT  41000.0         3.0  Mangalure
# 6        E007   Rohit  28.0    Finance  48000.0         4.0  Bangalore
# 7        E008   Meena  30.0         HR  50000.0         6.0     Mysore
# 8        E009   Vijay  24.0         IT  32000.0         1.0      Hubli
# 9        E010    Neha  27.0  Marketing  46000.0         4.0  Mangalure
#
#    Gender  Performance
# 0    Male         85.0
# 1  Female         90.0
# 2    Male         78.0
# 3  Female         88.0
# 4    Male         92.0
# 5  Female         81.0
# ...

# %%
data.isnull().sum()
# Out:
# Employee_ID    0
# Name           0
# Age            0
# Department     0
# Salary         0
# Experience     0
# City           0
# Gender         0
# Performance    0
# dtype: int64

# %%
data['Age']=data['Age'].fillna(30)
data
# Out:
#   Employee_ID    Name   Age Department   Salary  Experience       City  \
# 0        E001   Rahul  24.0         IT  35000.0         1.0  Bangalore
# 1        E002   Priya  27.0         HR  42000.0         3.0     Mysore
# 2        E003    Arun  24.0    Finance  50000.0         5.0  Bangalore
# 3        E004   Sneha  25.0         IT  50000.0         2.0      Hubli
# 4        E005   Kiran  31.0  Marketing  55000.0         8.0    Dharwad
# 5        E006  Anjali  26.0         IT  41000.0         3.0  Mangalure
# 6        E007   Rohit  28.0    Finance  48000.0         4.0  Bangalore
# 7        E008   Meena  30.0         HR  50000.0         6.0     Mysore
# 8        E009   Vijay  24.0         IT  32000.0         1.0      Hubli
# 9        E010    Neha  27.0  Marketing  46000.0         4.0  Mangalure
#
#    Gender  Performance
# 0    Male         85.0
# 1  Female         90.0
# 2    Male         78.0
# 3  Female         88.0
# 4    Male         92.0
# 5  Female         81.0
# ...

# %%
data.isnull().sum()
# Out:
# Employee_ID    0
# Name           0
# Age            0
# Department     0
# Salary         0
# Experience     0
# City           0
# Gender         0
# Performance    0
# dtype: int64

# %%
data.isnull().duplicated()
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# dtype: bool

# %%
data.isnull().duplicated().sum()
# Out:
# np.int64(9)

# %%
data.isnull().drop_duplicates()
data
# Out:
#   Employee_ID    Name   Age Department   Salary  Experience       City  \
# 0        E001   Rahul  24.0         IT  35000.0         1.0  Bangalore
# 1        E002   Priya  27.0         HR  42000.0         3.0     Mysore
# 2        E003    Arun  24.0    Finance  50000.0         5.0  Bangalore
# 3        E004   Sneha  25.0         IT  50000.0         2.0      Hubli
# 4        E005   Kiran  31.0  Marketing  55000.0         8.0    Dharwad
# 5        E006  Anjali  26.0         IT  41000.0         3.0  Mangalure
# 6        E007   Rohit  28.0    Finance  48000.0         4.0  Bangalore
# 7        E008   Meena  30.0         HR  50000.0         6.0     Mysore
# 8        E009   Vijay  24.0         IT  32000.0         1.0      Hubli
# 9        E010    Neha  27.0  Marketing  46000.0         4.0  Mangalure
#
#    Gender  Performance
# 0    Male         85.0
# 1  Female         90.0
# 2    Male         78.0
# 3  Female         88.0
# 4    Male         92.0
# 5  Female         81.0
# ...

# %%
data.isnull().sum()
# Out:
# Employee_ID    0
# Name           0
# Age            0
# Department     0
# Salary         0
# Experience     0
# City           0
# Gender         0
# Performance    0
# dtype: int64

# %%
data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
data['Name']=data['Name'].str.strip()
data
# Out:
#   Employee_ID    Name   Age Department   Salary  Experience       City  \
# 0        E001   Rahul  24.0         IT  35000.0         1.0  Bangalore
# 1        E002   Priya  27.0         HR  42000.0         3.0     Mysore
# 2        E003    Arun  24.0    Finance  50000.0         5.0  Bangalore
# 3        E004   Sneha  25.0         IT  50000.0         2.0      Hubli
# 4        E005   Kiran  31.0  Marketing  55000.0         8.0    Dharwad
# 5        E006  Anjali  26.0         IT  41000.0         3.0  Mangalure
# 6        E007   Rohit  28.0    Finance  48000.0         4.0  Bangalore
# 7        E008   Meena  30.0         HR  50000.0         6.0     Mysore
# 8        E009   Vijay  24.0         IT  32000.0         1.0      Hubli
# 9        E010    Neha  27.0  Marketing  46000.0         4.0  Mangalure
#
#    Gender  Performance
# 0    Male         85.0
# 1  Female         90.0
# 2    Male         78.0
# 3  Female         88.0
# 4    Male         92.0
# 5  Female         81.0
# ...

# %%
data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = data.drop_duplicates()
df
# Out:
#   Employee_ID    Name   Age Department   Salary  Experience       City  \
# 0        E001   Rahul  24.0         IT  35000.0         1.0  Bangalore
# 1        E002   Priya  27.0         HR  42000.0         3.0     Mysore
# 2        E003    Arun  24.0    Finance  50000.0         5.0  Bangalore
# 3        E004   Sneha  25.0         IT  50000.0         2.0      Hubli
# 4        E005   Kiran  31.0  Marketing  55000.0         8.0    Dharwad
# 5        E006  Anjali  26.0         IT  41000.0         3.0  Mangalure
# 6        E007   Rohit  28.0    Finance  48000.0         4.0  Bangalore
# 7        E008   Meena  30.0         HR  50000.0         6.0     Mysore
# 8        E009   Vijay  24.0         IT  32000.0         1.0      Hubli
# 9        E010    Neha  27.0  Marketing  46000.0         4.0  Mangalure
#
#    Gender  Performance
# 0    Male         85.0
# 1  Female         90.0
# 2    Male         78.0
# 3  Female         88.0
# 4    Male         92.0
# 5  Female         81.0
# ...

# %%
df['City']=df['City'].str.strip()
df
# Out:
#   Employee_ID    Name   Age Department   Salary  Experience       City  \
# 0        E001   Rahul  24.0         IT  35000.0         1.0  Bangalore
# 1        E002   Priya  27.0         HR  42000.0         3.0     Mysore
# 2        E003    Arun  24.0    Finance  50000.0         5.0  Bangalore
# 3        E004   Sneha  25.0         IT  50000.0         2.0      Hubli
# 4        E005   Kiran  31.0  Marketing  55000.0         8.0    Dharwad
# 5        E006  Anjali  26.0         IT  41000.0         3.0  Mangalure
# 6        E007   Rohit  28.0    Finance  48000.0         4.0  Bangalore
# 7        E008   Meena  30.0         HR  50000.0         6.0     Mysore
# 8        E009   Vijay  24.0         IT  32000.0         1.0      Hubli
# 9        E010    Neha  27.0  Marketing  46000.0         4.0  Mangalure
#
#    Gender  Performance
# 0    Male         85.0
# 1  Female         90.0
# 2    Male         78.0
# 3  Female         88.0
# 4    Male         92.0
# 5  Female         81.0
# ...

# %%
#import numpy as np
#df.loc[df['Age'] > 80, 'Age']=np.nan
#df
df.dtypes
# Out:
# Employee_ID     object
# Name            object
# Age            float64
# Department      object
# Salary         float64
# Experience     float64
# City            object
# Gender          object
# Performance    float64
# dtype: object

# %%
df['Age']  = df['Age'].astype(int)
df
# Out:
#   Employee_ID    Name  Age Department   Salary  Experience       City  Gender  \
# 0        E001   Rahul   24         IT  35000.0         1.0  Bangalore    Male
# 1        E002   Priya   27         HR  42000.0         3.0     Mysore  Female
# 2        E003    Arun   24    Finance  50000.0         5.0  Bangalore    Male
# 3        E004   Sneha   25         IT  50000.0         2.0      Hubli  Female
# 4        E005   Kiran   31  Marketing  55000.0         8.0    Dharwad    Male
# 5        E006  Anjali   26         IT  41000.0         3.0  Mangalure  Female
# 6        E007   Rohit   28    Finance  48000.0         4.0  Bangalore    Male
# 7        E008   Meena   30         HR  50000.0         6.0     Mysore  Female
# 8        E009   Vijay   24         IT  32000.0         1.0      Hubli    Male
# 9        E010    Neha   27  Marketing  46000.0         4.0  Mangalure  Female
#
#    Performance
# 0         85.0
# 1         90.0
# 2         78.0
# 3         88.0
# 4         92.0
# ...

# %%
df['Salary']  = df['Salary'].astype(int)
df
# Out:
#   Employee_ID    Name  Age Department  Salary  Experience       City  Gender  \
# 0        E001   Rahul   24         IT   35000         1.0  Bangalore    Male
# 1        E002   Priya   27         HR   42000         3.0     Mysore  Female
# 2        E003    Arun   24    Finance   50000         5.0  Bangalore    Male
# 3        E004   Sneha   25         IT   50000         2.0      Hubli  Female
# 4        E005   Kiran   31  Marketing   55000         8.0    Dharwad    Male
# 5        E006  Anjali   26         IT   41000         3.0  Mangalure  Female
# 6        E007   Rohit   28    Finance   48000         4.0  Bangalore    Male
# 7        E008   Meena   30         HR   50000         6.0     Mysore  Female
# 8        E009   Vijay   24         IT   32000         1.0      Hubli    Male
# 9        E010    Neha   27  Marketing   46000         4.0  Mangalure  Female
#
#    Performance
# 0         85.0
# 1         90.0
# 2         78.0
# 3         88.0
# 4         92.0
# 5         81.0
# ...

# %%
df['Gender'] = df['Gender'].replace({"M" : "Male","F" : "Female"})
df
# Out:
#   Employee_ID    Name  Age Department  Salary  Experience       City  Gender  \
# 0        E001   Rahul   24         IT   35000         1.0  Bangalore    Male
# 1        E002   Priya   27         HR   42000         3.0     Mysore  Female
# 2        E003    Arun   24    Finance   50000         5.0  Bangalore    Male
# 3        E004   Sneha   25         IT   50000         2.0      Hubli  Female
# 4        E005   Kiran   31  Marketing   55000         8.0    Dharwad    Male
# 5        E006  Anjali   26         IT   41000         3.0  Mangalure  Female
# 6        E007   Rohit   28    Finance   48000         4.0  Bangalore    Male
# 7        E008   Meena   30         HR   50000         6.0     Mysore  Female
# 8        E009   Vijay   24         IT   32000         1.0      Hubli    Male
# 9        E010    Neha   27  Marketing   46000         4.0  Mangalure  Female
#
#    Performance
# 0         85.0
# 1         90.0
# 2         78.0
# 3         88.0
# 4         92.0
# 5         81.0
# ...

# %%
data=df

# %%
print(df.columns)
# Out:
# Index(['Employee_ID', 'Name', 'Age', 'Department', 'Salary', 'Experience',
#        'City', 'Performance', 'Gender_Female', 'Gender_Male'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()
df
# Out:
#   Employee_ID    Name  Age Department  Salary  Experience       City  \
# 0        E001   Rahul   24         IT   35000         1.0  Bangalore
# 1        E002   Priya   27         HR   42000         3.0     Mysore
# 2        E003    Arun   24    Finance   50000         5.0  Bangalore
# 3        E004   Sneha   25         IT   50000         2.0      Hubli
# 4        E005   Kiran   31  Marketing   55000         8.0    Dharwad
# 5        E006  Anjali   26         IT   41000         3.0  Mangalure
# 6        E007   Rohit   28    Finance   48000         4.0  Bangalore
# 7        E008   Meena   30         HR   50000         6.0     Mysore
# 8        E009   Vijay   24         IT   32000         1.0      Hubli
# 9        E010    Neha   27  Marketing   46000         4.0  Mangalure
#
#    Performance  Gender_Female  Gender_Male
# 0         85.0          False         True
# 1         90.0           True        False
# 2         78.0          False         True
# ...

# %%
import pandas as pd

data = pd.get_dummies(data, columns=['Gender'], dtype=int)

data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_784/518213683.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 data = pd.get_dummies(data, columns=['Gender'], dtype=int)
#       4
#       5 data
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/reshape/encoding.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     167             raise TypeError("Input must be a list-like for parameter `columns`")
#     168         else:
# --> 169             data_to_encode = data[columns]
#     170
#     171         # validate prefixes and separator to avoid silently dropping cols
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Employee_ID', 'Name', 'Age', 'Department', 'Salary', 'Experience', 'City', 'Performance', 'Gender_Female', 'Gender_Male']

# %%
print(df[['Gender_Female', 'Gender_Male']])
# Out:
#    Gender_Female  Gender_Male
# 0          False         True
# 1           True        False
# 2          False         True
# 3           True        False
# 4          False         True
# 5           True        False
# 6          False         True
# 7           True        False
# 8          False         True
# 9           True        False

# %%
df[['Gender_Female', 'Gender_Male']] = df[['Gender_Female', 'Gender_Male']].astype(int)
df
# Out:
#   Employee_ID    Name  Age Department  Salary  Experience       City  \
# 0        E001   Rahul   24         IT   35000         1.0  Bangalore
# 1        E002   Priya   27         HR   42000         3.0     Mysore
# 2        E003    Arun   24    Finance   50000         5.0  Bangalore
# 3        E004   Sneha   25         IT   50000         2.0      Hubli
# 4        E005   Kiran   31  Marketing   55000         8.0    Dharwad
# 5        E006  Anjali   26         IT   41000         3.0  Mangalure
# 6        E007   Rohit   28    Finance   48000         4.0  Bangalore
# 7        E008   Meena   30         HR   50000         6.0     Mysore
# 8        E009   Vijay   24         IT   32000         1.0      Hubli
# 9        E010    Neha   27  Marketing   46000         4.0  Mangalure
#
#    Performance  Gender_Female  Gender_Male
# 0         85.0              0            1
# 1         90.0              1            0
# 2         78.0              0            1
# ...
